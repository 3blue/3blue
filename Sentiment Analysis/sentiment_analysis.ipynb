# %%
import numpy as np
import os
import csv
import random
import math
import string

# %%
from google.colab import drive 
drive.mount('/content/drive')
work_dir = '/content/drive/My Drive/NLP/Challenge 1'
os.chdir(work_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def preprocess(L):
  return L.translate(str.maketrans('', '', string.punctuation)).lower()

# %%
tsv_file = open("train.tsv")
read_tsv = csv.reader(tsv_file, delimiter="\t")

pwc = 0          #Total word count of positive/negative tweets, used in Naive Bayes calculation
nwc = 0
p_concat = ""    #Concatenation of all positive/negative text
n_concat = ""
x=0
for row in read_tsv:
  if len(row) == 2:
    if row[0] == '1':
      pwc = pwc + len(row[1].split(' '))
      p_concat += " " + row[1]
    else:
      nwc = nwc + len(row[1].split(' '))
      n_concat += " " + row[1]
print(p_concat)
p_concat = preprocess(p_concat)
print(p_concat)
#n_concat = preprocess(n_concat)
#V = list(set(p_concat.split(" ")).union(set(n_concat.split(" "))))
#print(V)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# this should return either 0 (negative sentiment) or 1 (positive sentiment)
def predict_from_scratch(tweet):
  p_pos = 1
  p_neg = 1
  for word in tweet:
    p_pos = p_pos * ((p_concat.count(word) + 1) / (pwc + len(pwc)))

# %%
# this should return either 0 (negative sentiment) or 1 (positive sentiment)
def predict_anything_goes(tweet):
  # do something complicated here
  return random.randint(0,1)

# %%
def evaluate():
  total = 0
  correct_from_scratch = 0
  correct_anything_goes = 0
  testfile = open('test.tsv', 'r')
  for line in testfile:
    total += 1
    pieces = line.rstrip("\n").split("\t")
    if predict_from_scratch(pieces[1]) == int(pieces[0]):
      correct_from_scratch += 1
    if predict_anything_goes(pieces[1]) == int(pieces[0]):
      correct_anything_goes += 1
  return (correct_from_scratch/total, correct_anything_goes/total)

# %%
evaluate()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-3f393ad04e6a> in <module>()
# ----> 1 evaluate()
#
# <ipython-input-9-5723f2fbfea6> in evaluate()
#       3   correct_from_scratch = 0
#       4   correct_anything_goes = 0
# ----> 5   testfile = open('test.tsv', 'r')
#       6   for line in testfile:
#       7     total += 1
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.tsv'
